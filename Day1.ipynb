# %% [markdown]
# ## 練習時間
# 請寫一個函式用來計算 Mean Square Error <br>
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# [作業目標]
# 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)
#
# [作業重點]
# 注意程式的縮排
# 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mse = MSE = sum(abs(y - yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 214.260
# The Mean absolute error is 11.511

# %% [markdown]
# #### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# Target: https://www.kaggle.com/madislemsalu/facebook-ad-campaign
#
# * 你選的這組資料為何重要
#
# 對於企業端來說，免費服務主要都是依廣告收看來盈利，越多廣告點擊，則企業營收越多
#
# * 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# Facebook 用戶內部廣告數據的一組小 subset
#
# * 蒐集而來的資料型態為何
#
# CSV結構化的檔案
#
# * 這組資料想解決的問題如何評估
#
# 主要看廣告點擊數 clicks 以及 total_conversion

# %% [markdown]
# #### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# * 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」):
#
# 假設，目前車行無法有效的派車，到本身用車需求量較高的路段，因此透過數據分析出搭車高峰路段，可以找出有潛在用車需求的地方，進而增加載客量，提升業績。
#
# * 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)：
#
# 車行本身需要有歷史載客數據（上車地點等資料）以及派車資料（車子主要被派往哪區），藉由比例（例如說：只有2％的車子被派往內湖區，但是5%的客戶上車起點都是內湖區）可以知道哪些地方算是搭車高峰地帶。
#
# * 蒐集而來的資料型態為何
#
# CSV格式化檔案，包含每一次派車，每一次搭乘等
#
# * 你要回答的問題，其如何評估
#
# 實際上派出更多車前往分析結果為「搭車高峰路段」的地方，看收益是否真實提升
